# %% [markdown]
# # **Notebook 5: Forma de los datos**
# ## Introduccion a Mapper

# %%
import kmapper as km
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import tadasets

# %%
np.random.seed(9)
x1 = tadasets.dsphere(n=500, d=1, r=5, noise=0.9)
x2 = tadasets.dsphere(n=500, d=1, r=5, noise=0.5)
x2 = [x+[6,6] for x in x2]
x = np.concatenate([x1, x2])
plt.scatter(x[:,0], x[:,1])
plt.axis('equal')
plt.show()

# %%
u1 = [-7,-3.5]
u2 = [-4.5,-0.5]
u3 = [-1.5,3.5]
u4 = [2.5,6.5]
u5 = [5.5,9.5]
u6 = [8.5,13]

import pandas as pd
df = pd.DataFrame(x, columns=['x', 'y'])
def classifier(x):
    if x[1]<u1[1]:
        return 1
    if x[1]<u2[1]:
        return 2
    if x[1]<u3[1]:
        return 3
    if x[1]<u4[1]:
        return 4
    if x[1]<u5[1]:
        return 5
    return 6

# %%
df["c"] = df.apply(classifier, axis=1)
# Out:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\43176829.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u1[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\43176829.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u2[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\43176829.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u3[1]:
# ...

# %%
plt.scatter(df['x'], df['y'], c=df['c'])

# %% [markdown]
# Cambiando las cubiertas u, y  cambiando la funcion

# %%
u1 = [-7,-3.5]
u2 = [-3,-0.5]
u3 = [-1,3.5]
u4 = [2,6.5]
u5 = [5,9.5]
u6 = [8,13]

# %%
df["c"] = df.apply(classifier, axis=1)
plt.scatter(df['x'], df['y'], c=df['c'])
# Out:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\43176829.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u1[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\43176829.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u2[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\43176829.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u3[1]:
# ...

# %%
u1 = [-7,-2.2]
u2 = [-2,3.2]
u3 = [3,8.2]
u4 = [8,13]

# %%
def classifier(x):
    if x[1]<u1[1]:
        return 1
    if x[1]<u2[1]:
        return 2
    if x[1]<u3[1]:
        return 3
    return 4

# %%
df["c"] = df.apply(classifier, axis=1)
plt.scatter(df['x'], df['y'], c=df['c'])
# Out:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\1265558258.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u1[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\1265558258.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u2[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\1265558258.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]<u3[1]:

# %%
df["suma"] = df['x']+df['y']
df["suma"].min(), df["suma"].max()
# Out:
# (-10.092449815914124, 20.892786600880846)

# %%
print(df["suma"].min(), df["suma"].max())
# Out:
# -10.092449815914124 20.892786600880846

# %%
u1 = [-11,-3.5]
u2 = [-4,2]
u3 = [2,8]
u4 = [8,14]
u5 = [14,23]

def classifier(x):
    if x[0]+ x[1]<u1[1]:
        return 1
    if x[0]+x[1]<u2[1]:
        return 2
    if x[0]+x[1]<u3[1]:
        return 3
    if x[0]+x[1]<u4[1]:
        return 4
    return 5

# %%
df["c"] = df.apply(classifier, axis=1)
plt.scatter(df['x'], df['y'], c=df['c'])
# Out:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\3887255914.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[0]+ x[1]<u1[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\3887255914.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[0]+x[1]<u2[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\3887255914.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %%
df["cuadrado"]= df['x']**2+df['y']**2
print(df["cuadrado"].min(), df["cuadrado"].max())
# Out:
# 2.4534499466799957 218.2543176723005

# %%
u1 = [4, 40]
u2 = [10, 80]
u3 = [20, 160]
u4 = [30, 240]

def classifier(x):
    if x[0]**2+x[1]**2<u1[1]:
        return 1
    if x[0]**2+x[1]**2<u2[1]:
        return 2
    if x[0]**2+x[1]**2<u3[1]:
        return 3
    return 4

# %%
df["c"] = df.apply(classifier, axis=1)
plt.scatter(df['x'], df['y'], c=df['c'])
# Out:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\513475756.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[0]**2+x[1]**2<u1[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\513475756.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[0]**2+x[1]**2<u2[1]:
# C:\Users\Franco Mendoza\AppData\Local\Temp\ipykernel_5652\513475756.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %%
mapper = km.KeplerMapper(verbose=1)
# La proyeccion sobre el math score, corresponde a proyectar sobre la primera columna de data
projected_data = mapper.fit_transform(x, projection=[1]) # Math score
# Out:
# KeplerMapper(verbose=1)
# ..Composing projection pipeline of length 1:
# 	Projections: [1]
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (1000, 2)
#
# ..Projecting data using: [1]
#
# ..Scaling with: MinMaxScaler()

# %%
covering = km.Cover(n_cubes=7, perc_overlap=0.2)
covering
# Out:
# Cover(n_cubes=7, perc_overlap=0.2, limits=None, verbose=0)

# %%
G = mapper.map(projected_data, X=x, cover=covering, clusterer=sklearn.cluster.KMeans(n_clusters=2))
# Out:
# Mapping on data shaped (1000, 2) using lens shaped (1000, 1)
#
# Creating 7 hypercubes.
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
G['meta_data']
# Out:
# {'projection': '[1]',
#  'n_cubes': 7,
#  'perc_overlap': 0.2,
#  'clusterer': 'KMeans(n_clusters=2)',
#  'scaler': 'MinMaxScaler()'}

# %%
mapper.visualize(G, title = "Example 1 of Mapper on the Sphere dataset",
                 color_values = x[:,1],
                 color_function_name = "Height of the point",
                 node_color_function=np.array(['average','std','sum','max','min']))
# Out:
# Wrote visualization to: mapper_visualization_output.html
# ...
